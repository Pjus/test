# %%
import os
os.chdir('../../')
os.getcwd()
# Out:
# 'D:\\SD_python\\test'

# %%
from get_stock_data import data_gan
data_gan()
# Out:
# Input Stock Code :
# AAPL
# Start Date YYYY-MM-DD :
# 2015-05-05
